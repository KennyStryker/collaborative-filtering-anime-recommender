# %%
import pandas as pd
from collections import defaultdict
import re
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rating = pd.read_csv('C:\\Users\\Kenny\\Desktop\\Stuff\\collaborative-filtering-anime-recommender\\dataset\\raw\\rating.csv')
anime_df = pd.read_csv('C:\\Users\\Kenny\\Desktop\\Stuff\\collaborative-filtering-anime-recommender\\dataset\\raw\\anime.csv')

# %%
rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
null_features = anime_df.columns[anime_df.isna().any()]
anime_df[null_features].isna().sum()
anime_df.dropna(inplace=True)

# %%
def text_cleaning(text):
    text = re.sub(r'&quot;', '', text)
    text = re.sub(r'.hack//', '', text)
    text = re.sub(r'&#039;', '', text)
    text = re.sub(r'A&#039;s', '', text)
    text = re.sub(r'I&#039;', 'I\'', text)
    text = re.sub(r'&amp;', 'and', text)
    
    return text

# %%
tqdm.pandas()
anime_df['name'] = anime_df['name'].progress_apply(text_cleaning)
# Out:
# E:\Anaconda3\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 12017/12017 [00:00<00:00, 211392.51it/s]

# %%
plt.tight_layout()
plt.show()
